# %% [markdown]
# # Create the design space to take data
#
# The paper uses a Latin hypercube to do a space filling design with conservative boundaries for 20 experiments.

# %%
#Define Boundaries for each feature

##Continuous features should be distributed between [0, upper_bound]
NaCl_boundaries = [0,140]
LArginine_boundaries = [0,150]
LLysine_boundaries = [0,150]
LProline_boundaries = [0,150]

#Discrete features are [0, upper_bound]
pH_boundaries = [5,5.5,6,6.5]
Trehalose_boundaries = [0,8]
Mannitol_boundaries = [0,4]
Tween20_boundaries = [0,0.01]

# %% [markdown]
# ## Initial Round Design Space

# %% [markdown]
# ### Construct a Latin hypercube

# %%
#using SMT: Surrogate Modeling Toolbox
from smt.sampling_methods import LHS

##Generate the continuous variables data points
continuous_variables_boundaries = np.array([NaCl_boundaries, 
                                            LArginine_boundaries, 
                                            LLysine_boundaries, 
                                            LProline_boundaries])
sampling = LHS(xlimits=continuous_variables_boundaries)

num = 20    #initial 20 experiments
continuous_variables_ = sampling(num)
continuous_variables_
# Out:
# array([[ 38.5 ,  41.25,  18.75, 101.25],
#        [101.5 ,  93.75, 108.75, 146.25],
#        [ 87.5 , 146.25,   3.75,  56.25],
#        [ 31.5 ,  26.25,  41.25,  26.25],
#        [ 52.5 ,  86.25, 146.25,  78.75],
#        [115.5 ,  63.75,  11.25,  63.75],
#        [ 59.5 , 101.25,  56.25,  86.25],
#        [129.5 , 138.75,  63.75,  18.75],
#        [ 80.5 ,  56.25,  86.25,   3.75],
#        [ 94.5 , 108.75, 131.25,  11.25],
#        [ 10.5 ,  78.75, 116.25, 138.75],
#        [ 45.5 ,  18.75, 101.25, 108.75],
#        [ 73.5 ,  33.75, 123.75,  33.75],
#        [ 66.5 ,  11.25,  33.75,  41.25],
#        [108.5 , 116.25,  48.75, 131.25],
#        [122.5 ,  71.25,  78.75,  71.25],
#        [ 24.5 ,  48.75,  26.25, 123.75],
#        [  3.5 , 131.25, 138.75, 116.25],
#        [ 17.5 ,   3.75,  93.75,  48.75],
#        [136.5 , 123.75,  71.25,  93.75]])

# %%
import random

##Generate the discrete variables data points
discrete_variables_ = np.array([random.choices(pH_boundaries, k=20), 
                                random.choices(Mannitol_boundaries, k=20),
                                random.choices(Tween20_boundaries, k=20),
                                random.choices(Trehalose_boundaries, k=20)]).T

discrete_variables_
# Out:
# array([[5.5 , 0.  , 0.  , 8.  ],
#        [6.  , 0.  , 0.  , 0.  ],
#        [6.5 , 4.  , 0.  , 8.  ],
#        [5.5 , 0.  , 0.  , 8.  ],
#        [5.  , 4.  , 0.  , 8.  ],
#        [5.5 , 0.  , 0.  , 8.  ],
#        [6.  , 0.  , 0.01, 0.  ],
#        [5.  , 0.  , 0.  , 8.  ],
#        [5.  , 0.  , 0.  , 8.  ],
#        [5.  , 4.  , 0.  , 0.  ],
#        [5.  , 4.  , 0.01, 8.  ],
#        [5.5 , 4.  , 0.  , 0.  ],
#        [5.  , 0.  , 0.01, 0.  ],
#        [5.5 , 4.  , 0.  , 0.  ],
#        [5.  , 4.  , 0.  , 0.  ],
#        [6.5 , 4.  , 0.  , 0.  ],
#        [6.  , 4.  , 0.01, 0.  ],
#        [6.5 , 4.  , 0.01, 0.  ],
#        [6.  , 4.  , 0.01, 8.  ],
#        [5.5 , 0.  , 0.01, 8.  ]])

# %%
import pandas as pd

#merge both, continuous and discrete data points
initial_data_points = np.concatenate((continuous_variables_, discrete_variables_), axis=1)

#create a pandas dataframe
column_values = ['NaCl', 'LArginine', 'LLysine', 'LProline_boundaries', 'pH', 
                 'Mannitol', 'Tween20', 'Trehalose']
df_initial = pd.DataFrame(data = initial_data_points,
                          columns = column_values)
df_initial
# Out:
#      NaCl  LArginine  LLysine  LProline_boundaries   pH  Mannitol  Tween20  \
# 0    38.5      41.25    18.75               101.25  5.5       0.0     0.00
# 1   101.5      93.75   108.75               146.25  6.0       0.0     0.00
# 2    87.5     146.25     3.75                56.25  6.5       4.0     0.00
# 3    31.5      26.25    41.25                26.25  5.5       0.0     0.00
# 4    52.5      86.25   146.25                78.75  5.0       4.0     0.00
# 5   115.5      63.75    11.25                63.75  5.5       0.0     0.00
# 6    59.5     101.25    56.25                86.25  6.0       0.0     0.01
# 7   129.5     138.75    63.75                18.75  5.0       0.0     0.00
# 8    80.5      56.25    86.25                 3.75  5.0       0.0     0.00
# 9    94.5     108.75   131.25                11.25  5.0       4.0     0.00
# 10   10.5      78.75   116.25               138.75  5.0       4.0     0.01
# 11   45.5      18.75   101.25               108.75  5.5       4.0     0.00
# 12   73.5      33.75   123.75                33.75  5.0       0.0     0.01
# 13   66.5      11.25    33.75                41.25  5.5       4.0     0.00
# 14  108.5     116.25    48.75               131.25  5.0       4.0     0.00
# 15  122.5      71.25    78.75                71.25  6.5       4.0     0.00
# 16   24.5      48.75    26.25               123.75  6.0       4.0     0.01
# 17    3.5     131.25   138.75               116.25  6.5       4.0     0.01
# 18   17.5       3.75    93.75                48.75  6.0       4.0     0.01
# 19  136.5     123.75    71.25                93.75  5.5       0.0     0.01
#
#     Trehalose
# 0         8.0
# 1         0.0
# 2         8.0
# 3         8.0
# 4         8.0
# 5         8.0
# 6         0.0
# 7         8.0
# 8         8.0
# 9         0.0
# 10        8.0
# 11        0.0
# 12        0.0
# 13        0.0
# 14        0.0
# 15        0.0
# 16        0.0
# 17        0.0
# 18        8.0
# 19        8.0

# %%
import seaborn as sns
sns.pairplot(data=df_initial)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Extract 𝜈, 𝜃 from the Matern kernel by fitting the training data of the initial round

# %%
#Using the data provided as initial round by the authors

import pandas as pd

data = pd.read_excel('mp1c00469_si_002.xlsx')
data[data.Round == 'Intial']
# Out:
#      Round  Exp No.   pH  NaCl (mM)  Trehalose (w/v %)  Mannitol (w/v %)  \
# 0   Intial        1  5.0      15.00                7.0               0.0
# 1   Intial        3  5.0      18.33                1.0               3.0
# 2   Intial        4  5.5      11.67                5.0               5.0
# 3   Intial        5  6.0       8.33                4.0               4.0
# 4   Intial        6  6.0      41.67                7.0               0.0
# 5   Intial        7  6.0       1.67                2.0               2.0
# 6   Intial        8  6.0      25.00                7.0               3.0
# 7   Intial        9  6.0      45.00                1.0               5.0
# 8   Intial       10  6.0      48.33                4.0               5.0
# 9   Intial       11  6.0      38.33                0.0               2.0
# 10  Intial       12  6.0      31.67                9.0               3.0
# 11  Intial       13  6.5      28.33                3.0               3.0
# 12  Intial       14  6.5      35.00                5.0               2.0
# 13  Intial       15  6.5       5.00                5.0               3.0
#
#     Tween 20 (v/v%)         Tm         NP    NP_std
# 0             0.010  59.347822   9.125637  1.308154
# 1             0.000  59.453012  15.327258  3.096163
# 2             0.001  61.820366  22.564530  1.232968
# 3             0.100  62.133793   5.018450  2.799784
# 4             0.000  61.224976  14.055202  3.378255
# 5             0.010  61.736058  30.172069  2.211314
# 6             0.010  62.291090  15.544041  2.527973
# 7             0.100  60.964890   5.468750  1.802194
# 8             0.000  61.654499  18.791118  2.265397
# 9             0.100  60.502291   6.504673  3.503012
# 10            0.001  62.224765  24.222314  2.249926
# 11            0.000  61.837666  20.329218  1.285268
# 12            0.010  62.433232  16.893204  1.230190
# 13            0.001  62.175092  19.178082  1.265036

# %%
#We only need the excepients + pH and the Target temperature Tm

df_initial_train = data.query("Round == 'Intial'")
df_initial_train
# Out:
#      Round  Exp No.   pH  NaCl (mM)  Trehalose (w/v %)  Mannitol (w/v %)  \
# 0   Intial        1  5.0      15.00                7.0               0.0
# 1   Intial        3  5.0      18.33                1.0               3.0
# 2   Intial        4  5.5      11.67                5.0               5.0
# 3   Intial        5  6.0       8.33                4.0               4.0
# 4   Intial        6  6.0      41.67                7.0               0.0
# 5   Intial        7  6.0       1.67                2.0               2.0
# 6   Intial        8  6.0      25.00                7.0               3.0
# 7   Intial        9  6.0      45.00                1.0               5.0
# 8   Intial       10  6.0      48.33                4.0               5.0
# 9   Intial       11  6.0      38.33                0.0               2.0
# 10  Intial       12  6.0      31.67                9.0               3.0
# 11  Intial       13  6.5      28.33                3.0               3.0
# 12  Intial       14  6.5      35.00                5.0               2.0
# 13  Intial       15  6.5       5.00                5.0               3.0
#
#     Tween 20 (v/v%)         Tm         NP    NP_std
# 0             0.010  59.347822   9.125637  1.308154
# 1             0.000  59.453012  15.327258  3.096163
# 2             0.001  61.820366  22.564530  1.232968
# 3             0.100  62.133793   5.018450  2.799784
# 4             0.000  61.224976  14.055202  3.378255
# 5             0.010  61.736058  30.172069  2.211314
# 6             0.010  62.291090  15.544041  2.527973
# 7             0.100  60.964890   5.468750  1.802194
# 8             0.000  61.654499  18.791118  2.265397
# 9             0.100  60.502291   6.504673  3.503012
# 10            0.001  62.224765  24.222314  2.249926
# 11            0.000  61.837666  20.329218  1.285268
# 12            0.010  62.433232  16.893204  1.230190
# 13            0.001  62.175092  19.178082  1.265036

# %%
df_initial_train_features = df_initial_train.drop(['Round', 'Exp No.', 'Tm', 'NP', 'NP_std'], axis=1)
df_initial_train_features
# Out:
#      pH  NaCl (mM)  Trehalose (w/v %)  Mannitol (w/v %)  Tween 20 (v/v%)
# 0   5.0      15.00                7.0               0.0            0.010
# 1   5.0      18.33                1.0               3.0            0.000
# 2   5.5      11.67                5.0               5.0            0.001
# 3   6.0       8.33                4.0               4.0            0.100
# 4   6.0      41.67                7.0               0.0            0.000
# 5   6.0       1.67                2.0               2.0            0.010
# 6   6.0      25.00                7.0               3.0            0.010
# 7   6.0      45.00                1.0               5.0            0.100
# 8   6.0      48.33                4.0               5.0            0.000
# 9   6.0      38.33                0.0               2.0            0.100
# 10  6.0      31.67                9.0               3.0            0.001
# 11  6.5      28.33                3.0               3.0            0.000
# 12  6.5      35.00                5.0               2.0            0.010
# 13  6.5       5.00                5.0               3.0            0.001

# %%
df_initial_train_target = df_initial_train.Tm
df_initial_train_target
# Out:
# 0     59.347822
# 1     59.453012
# 2     61.820366
# 3     62.133793
# 4     61.224976
# 5     61.736058
# 6     62.291090
# 7     60.964890
# 8     61.654499
# 9     60.502291
# 10    62.224765
# 11    61.837666
# 12    62.433232
# 13    62.175092
# Name: Tm, dtype: float64

# %%
#RobustScaler uses central tendency metrics that are less sensitive to outliers.
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
values = scaler.fit(df_initial_train_features).transform(df_initial_train_features)
values
# Out:
# array([[-1.        , -0.46669334,  0.58823529, -1.71428571,  0.46153846],
#        [-1.        , -0.33346669, -0.82352941,  0.        , -0.56410256],
#        [-0.5       , -0.59991998,  0.11764706,  1.14285714, -0.46153846],
#        [ 0.        , -0.73354671, -0.11764706,  0.57142857,  9.69230769],
#        [ 0.        ,  0.60032006,  0.58823529, -1.71428571, -0.56410256],
#        [ 0.        , -1.        , -0.58823529, -0.57142857,  0.46153846],
#        [ 0.        , -0.06661332,  0.58823529,  0.        ,  0.46153846],
#        [ 0.        ,  0.73354671, -0.82352941,  1.14285714,  9.69230769],
#        [ 0.        ,  0.86677335, -0.11764706,  1.14285714, -0.56410256],
#        [ 0.        ,  0.46669334, -1.05882353, -0.57142857,  9.69230769],
#        [ 0.        ,  0.20024005,  1.05882353,  0.        , -0.46153846],
#        [ 0.5       ,  0.06661332, -0.35294118,  0.        , -0.56410256],
#        [ 0.5       ,  0.33346669,  0.11764706, -0.57142857,  0.46153846],
#        [ 0.5       , -0.86677335,  0.11764706,  0.        , -0.46153846]])

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# We can use Randomized search to get the best parameters for the gaussian fit

#from myGPR import MyGPR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.gaussian_process.kernels import Matern
from scipy import stats


param_grid = [{
    "alpha":  [1e-2, 1e-3],
    "kernel": [Matern(length_scale=l, nu=n,  length_scale_bounds=(1e-05, 100000.0)) 
                                            for l in stats.norm(10, 2).rvs(size=15)
                                            for n in [1.5, 2.5]]
}]

# scores for regression
scores = ['r2']

#gp = MyGPR()

gp = GaussianProcessRegressor(n_restarts_optimizer=5)
print("# Tuning hyper-parameters for %s" % score)
print()

clf = GridSearchCV(estimator=gp, param_grid=param_grid, cv=4,
                       scoring='%s' % score)
clf.fit(values, df_initial_train_target)
print(clf.best_params_)
# Out:
# # Tuning hyper-parameters for r2
# /home/stephy/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/stephy/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# {'alpha': 0.001, 'kernel': Matern(length_scale=9.74, nu=1.5)}
# /home/stephy/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)

# %%
#best hyperparameters: {'alpha': 0.001, 'kernel': Matern(length_scale=9.74, nu=1.5)}

tuned_gp =  GaussianProcessRegressor(kernel = Matern(length_scale=9.74, nu=1.5, 
                                                     length_scale_bounds=(1e-05, 100000.0)), 
                                              n_restarts_optimizer=5)
